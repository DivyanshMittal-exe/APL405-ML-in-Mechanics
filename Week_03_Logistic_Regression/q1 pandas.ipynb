# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import dataframe_image as dfi
pd.options.mode.chained_assignment = None

plt.style.use('ggplot')

# %%
df = pd.read_csv('weather_train.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  Humidity9am  \
# 0           W           44.0          W  ...         24.0         71.0
# 1         WNW           44.0        NNW  ...         22.0         44.0
# 2         WSW           46.0          W  ...         26.0         38.0
# 3          NE           24.0         SE  ...          9.0         45.0
# 4           W           41.0        ENE  ...         20.0         82.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
dfi.export(df.head(),"basic.png")

# %%
        df = df.replace(to_replace ="Yes",value =1)
        df = df.replace(to_replace ="No",value =0)

# %%
df = df.select_dtypes(exclude=['object'])

# %%
dfi.export(df.head(),"objd.png")

# %%
df = df.fillna(value=df.mean())

# %%
dfi.export(df.head(),"mean.png")

# %%
df = (df.iloc[:, :-1] - df.iloc[:, :-1].min()) /(df.iloc[:, :-1].max() - df.iloc[:, :-1].min())

# %%
dfi.export(df.head(),"normalise.png")
